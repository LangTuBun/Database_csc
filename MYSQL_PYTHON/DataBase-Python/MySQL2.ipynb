# %%
# %load_ext sql

# %%
host = '127.0.0.1',
user= 'root',
password='123456',
database='humanresources',
port = 3306

# %%
conn = 'mysql+pymysql://root:123456@127.0.0.1:3306/humanresources'
# %sql $conn

# %%
result1 = %sql select * from employees limit 5
# 1 dòng
result1.DataFrame()
result1
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/humanresources
# 5 rows affected.
# [(100, 'Steven', 'King', 'SKING', '515.123.4567', '2003-06-17 00:00:00', 'AD_PRES', Decimal('24000.00'), None, None, 90),
#  (101, 'Neena', 'Kochhar', 'NKOCHHAR', '515.123.4568', '2005-09-21 00:00:00', 'AD_VP', Decimal('17000.00'), None, 100, 90),
#  (102, 'Lex', 'De Haan', 'LDEHAAN', '515.123.4569', '2001-01-13 00:00:00', 'AD_VP', Decimal('17000.00'), None, 100, 90),
#  (103, 'Alexander', 'Hunold', 'AHUNOLD', '590.423.4567', '2006-01-03 00:00:00', 'IT_PROG', Decimal('9000.00'), None, 102, 60),
#  (104, 'Bruce', 'Ernst', 'BERNST', '590.423.4568', '2007-05-21 00:00:00', 'IT_PROG', Decimal('6000.00'), None, 103, 60)]

# %%
# %%sql result2 <<
# select *
# from employees
# limit 5
#
#
# #viết nhiều dòng
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/humanresources
# 5 rows affected.
# Returning data to local variable result2

# %%
df2 = result2.DataFrame()
df2.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0          100     Steven      King     SKING  515.123.4567
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567
# 4          104      Bruce     Ernst    BERNST  590.423.4568
#
#              HIRE_DATE   JOB_ID    SALARY COMMISSION_PCT  MANAGER_ID  \
# 0  2003-06-17 00:00:00  AD_PRES  24000.00           None         NaN
# 1  2005-09-21 00:00:00    AD_VP  17000.00           None       100.0
# 2  2001-01-13 00:00:00    AD_VP  17000.00           None       100.0
# 3  2006-01-03 00:00:00  IT_PROG   9000.00           None       102.0
# 4  2007-05-21 00:00:00  IT_PROG   6000.00           None       103.0
#
#    DEPARTMENT_ID
# 0             90
# 1             90
# 2             90
# 3             60
# 4             60

# %%
from_salary = int(input('Từ: '))
to_salary = int(input('Đến: ')) 
# %sql select * from employees where salary between :from_salary and :to_salary limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/humanresources
# 5 rows affected.
# [(103, 'Alexander', 'Hunold', 'AHUNOLD', '590.423.4567', '2006-01-03 00:00:00', 'IT_PROG', Decimal('9000.00'), None, 102, 60),
#  (104, 'Bruce', 'Ernst', 'BERNST', '590.423.4568', '2007-05-21 00:00:00', 'IT_PROG', Decimal('6000.00'), None, 103, 60),
#  (109, 'Daniel', 'Faviet', 'DFAVIET', '515.124.4169', '2002-08-16 00:00:00', 'FI_ACCOUNT', Decimal('9000.00'), None, 108, 100),
#  (110, 'John', 'Chen', 'JCHEN', '515.124.4269', '2005-09-28 00:00:00', 'FI_ACCOUNT', Decimal('8200.00'), None, 108, 100),
#  (111, 'Ismael', 'Sciarra', 'ISCIARRA', '515.124.4369', '2005-09-30 00:00:00', 'FI_ACCOUNT', Decimal('7700.00'), None, 108, 100)]
